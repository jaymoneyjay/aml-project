# %% [markdown]
# # Task 3: Read in data and Plot

# %%
import pickle
import gzip
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %% [markdown]
# ### Helper functions

# %%
def load_zipped_pickle(filename):
    with gzip.open(filename, 'rb') as f:
        loaded_object = pickle.load(f)
        return loaded_object

# %% [markdown]
# ### Load data

# %%
# load data
train_data = load_zipped_pickle("data/train.pkl")
test_data = load_zipped_pickle("data/test.pkl")
samples = load_zipped_pickle("data/sample.pkl")

# %%
# for contrast optimization, not used
# plt.hist(single_frame.ravel(), bins=256, range=(0.0, 255), fc='k', ec='k')

# %% [markdown]
# ## Plot a few frames for a chosen video {video_nr}
#
# plot images with and without labeled frames

# %%
train_data[0].keys()
# Out:
# dict_keys(['name', 'video', 'box', 'label', 'frames', 'dataset'])

# %%
video_nr = 0
add_frames = [12, 55, 88]

video = train_data[video_nr]['video']
boxes = train_data[video_nr]['box']
label = train_data[video_nr]['label']
frames = train_data[video_nr]['frames']

dataset = train_data[video_nr]['dataset']

frames_to_plot = frames + add_frames


for frame in frames_to_plot:
    fig = plt.figure(figsize=(8,6))
    ax = fig.subplots()
    plt.imshow(video[:,:,frame], interpolation='nearest')
    plt.imshow(box, alpha = 0.4)
    plt.imshow(label[:,:,frame], alpha = 0.5)
    ax.set_title(f'frame {frame}, dataset {dataset}')
    plt.colorbar()

# %%
train_data[64]['video'].shape
# Out:
# (579, 844, 116)

# %%
train_data[0]['video'].shape
# Out:
# (112, 112, 196)

# %%
train_data[0]['box'].shape
# Out:
# (112, 112)

# %%
train_data[63]['video'].shape
# Out:
# (731, 834, 95)

# %%
train_data[63]['box'].shape
# Out:
# (731, 834)

# %%
train_data[63]['label'].shape
# Out:
# (731, 834, 95)

# %%
train_data[63]['frames']
# Out:
# [2, 7, 13]

# %%
train_data[0]['video'][:,:,0].shape
# Out:
# (112, 112)
